# %% [markdown]
# <div style="border: 2px solid darkred;
#             color: darkred;
#             display: fill;
#             border-radius: 5px;
#             background-color: lightgray;
#             font-size: 100%;
#             font-family: Verdana;
#             letter-spacing: 0.4px;
#             text-align: justify; /* Align text and create even lines */
#             padding: 20px;"> <!-- Added padding to create paragraph shape -->
#   <p style="margin: 0;"> <!-- Removed padding from the paragraph style -->
#   <h5><strong>📌 What is YOLO?</strong></h5><br> You Only Look Once (YOLO) is a cutting-edge <strong>object detection</strong> method that significantly speeds up and simplifies the process of identifying objects in images and videos. Unlike traditional approaches, YOLO treats object detection as a single step, predicting object positions and categories directly.<br> By doing so, it achieves real-time detection without sacrificing accuracy. YOLO's neural network architecture processes images swiftly, making it valuable for applications like self-driving cars, surveillance, and robotics.<br> YOLO's unique approach has revolutionized object detection by making it faster and more accessible while maintaining high performance.
# </p>
# </div>

# %% [markdown]
# <div style="border: 2px solid darkred; /* Add border around the box */
#            color: darkred;
#            display: fill;
#            border-radius: 5px;
#            background-color: lightgray;
#            font-size: 100%;
#            font-family: Verdana;
#            letter-spacing: 0.8px">
#   <h1 style="padding: 20px 20px;  /* Equal padding on top and bottom */
#            color: darkred;
#            margin: 0; /* Remove default margin to prevent extra space */
#            text-align: center;"><strong>YOLOv10 Object Detection                                                    </strong></h1>
# </div>

# %% [markdown]
# ### **Importing Libraries**

# %%
import numpy as np
import PIL
import os
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
from glob import glob
import random
import cv2
import warnings
warnings.simplefilter('ignore')

# %%
# !pip install ultralytics

# %%
import ultralytics
from ultralytics import YOLO
yolo_model = YOLO("yolov10m.pt")

# %%
def ODImage(image):
    yolo_outputs = yolo_model.predict(image)
    output = yolo_outputs[0]
    box = output.boxes
    names = output.names
    for j in range(len(box)):
        labels = names[box.cls[j].item()]
        coordinates = box.xyxy[j].tolist()
        confidence = np.round(box.conf[j].item(), 2)
        print(f'Object {j + 1} is: {labels}')
        print(f'Coordinates are: {coordinates}')
        print(f'Confidence is: {confidence}')
        print('-------')
    NewImage = output.plot()[:, :, ::-1]
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(cv2.imread(
        image, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(NewImage)
    plt.axis('off')
    plt.title('OD Image')
    plt.show()

# %%
ODImage('G:\Hesham_DL\Object Detection\digits\_20170531_114926.JPG')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\digits\_20170531_114926.JPG: 352x640 1 stop sign, 26.7ms
# Speed: 2.8ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
# Object 1 is: stop sign
# Coordinates are: [26.082311630249023, 21.897966384887695, 2954.9990234375, 1492.48779296875]
# Confidence is: 0.73
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\flowers\0001.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\flowers\0001.jpg: 640x480 (no detections), 284.2ms
# Speed: 6.0ms preprocess, 284.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)

# %%
ODImage(r'G:\Hesham_DL\Object Detection\People\00000767.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\People\00000767.jpg: 448x640 1 person, 297.5ms
# Speed: 5.9ms preprocess, 297.5ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# Object 1 is: person
# Coordinates are: [252.13853454589844, 70.7729721069336, 632.6764526367188, 692.394287109375]
# Confidence is: 0.96
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\streets\vid_4_10140.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\streets\vid_4_10140.jpg: 384x640 1 car, 194.0ms
# Speed: 4.6ms preprocess, 194.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Object 1 is: car
# Coordinates are: [0.5867871642112732, 202.08419799804688, 77.52510070800781, 233.34449768066406]
# Confidence is: 0.86
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\drones\3.JPEG')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\drones\3.JPEG: 384x640 1 airplane, 282.3ms
# Speed: 4.6ms preprocess, 282.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Object 1 is: airplane
# Coordinates are: [628.24072265625, 681.5686645507812, 863.2542724609375, 796.4984130859375]
# Confidence is: 0.33
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\drones\1.JPEG')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\drones\1.JPEG: 416x640 1 airplane, 304.8ms
# Speed: 5.5ms preprocess, 304.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# Object 1 is: airplane
# Coordinates are: [292.8956604003906, 149.4480438232422, 936.8499755859375, 681.942626953125]
# Confidence is: 0.83
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\guns\1.jpeg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\guns\1.jpeg: 288x640 1 person, 1 cell phone, 1 oven, 235.4ms
# Speed: 3.7ms preprocess, 235.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# Object 1 is: person
# Coordinates are: [99.67802429199219, 7.680570602416992, 257.5260009765625, 143.15821838378906]
# Confidence is: 0.94
# -------
# Object 2 is: cell phone
# Coordinates are: [86.04106903076172, 48.164913177490234, 138.8931121826172, 87.2671890258789]
# Confidence is: 0.64
# -------
# Object 3 is: oven
# Coordinates are: [0.21825331449508667, 74.1075668334961, 120.43260955810547, 141.46548461914062]
# Confidence is: 0.27
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\People\00000864.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\People\00000864.jpg: 512x640 1 person, 1 tie, 332.3ms
# Speed: 88.1ms preprocess, 332.3ms inference, 10.1ms postprocess per image at shape (1, 3, 512, 640)
# Object 1 is: person
# Coordinates are: [5.54612922668457, 37.94557189941406, 920.623046875, 773.4359741210938]
# Confidence is: 0.96
# -------
# Object 2 is: tie
# Coordinates are: [223.54983520507812, 473.2471618652344, 391.0216369628906, 775.6596069335938]
# Confidence is: 0.89
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\People\00000876.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\People\00000876.jpg: 512x640 1 person, 1 sandwich, 322.3ms
# Speed: 5.9ms preprocess, 322.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
# Object 1 is: person
# Coordinates are: [242.79864501953125, 52.85560989379883, 1276.2774658203125, 1042.99072265625]
# Confidence is: 0.98
# -------
# Object 2 is: sandwich
# Coordinates are: [484.8305969238281, 588.5264282226562, 662.1404418945312, 717.5066528320312]
# Confidence is: 0.88
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\People\00000866.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\People\00000866.jpg: 416x640 1 person, 209.2ms
# Speed: 4.4ms preprocess, 209.2ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# Object 1 is: person
# Coordinates are: [944.5302734375, 2.516343116760254, 2034.287109375, 1256.232421875]
# Confidence is: 0.92
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\People\00000770.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\People\00000770.jpg: 448x640 1 person, 239.4ms
# Speed: 10.6ms preprocess, 239.4ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Object 1 is: person
# Coordinates are: [140.990966796875, 25.755840301513672, 443.25762939453125, 390.4197998046875]
# Confidence is: 0.96
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\streets\vid_4_9940.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\streets\vid_4_9940.jpg: 384x640 (no detections), 248.6ms
# Speed: 4.0ms preprocess, 248.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
ODImage(r'G:\Hesham_DL\Object Detection\streets\vid_4_10060.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\streets\vid_4_10060.jpg: 384x640 1 car, 236.0ms
# Speed: 4.1ms preprocess, 236.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Object 1 is: car
# Coordinates are: [33.80838394165039, 200.87001037597656, 124.12896728515625, 230.66445922851562]
# Confidence is: 0.87
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\streets\vid_4_10260.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\streets\vid_4_10260.jpg: 384x640 1 person, 1 fire hydrant, 183.1ms
# Speed: 4.5ms preprocess, 183.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Object 1 is: fire hydrant
# Coordinates are: [517.8884887695312, 195.90945434570312, 525.4657592773438, 212.01202392578125]
# Confidence is: 0.71
# -------
# Object 2 is: person
# Coordinates are: [634.6861572265625, 166.6300811767578, 643.8540649414062, 190.5296630859375]
# Confidence is: 0.28
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\streets\vid_4_10420.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\streets\vid_4_10420.jpg: 384x640 (no detections), 264.4ms
# Speed: 4.1ms preprocess, 264.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
ODImage(r'G:\Hesham_DL\Object Detection\fruits\banana_63.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\fruits\banana_63.jpg: 576x640 3 bananas, 313.8ms
# Speed: 11.5ms preprocess, 313.8ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
# Object 1 is: banana
# Coordinates are: [87.24642944335938, 49.47529983520508, 1210.641845703125, 706.6529541015625]
# Confidence is: 0.9
# -------
# Object 2 is: banana
# Coordinates are: [264.0780944824219, 671.0835571289062, 738.7708129882812, 923.6826782226562]
# Confidence is: 0.74
# -------
# Object 3 is: banana
# Coordinates are: [603.6441650390625, 669.7308349609375, 738.12548828125, 864.43994140625]
# Confidence is: 0.31
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\fruits\apple_39.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\fruits\apple_39.jpg: 384x640 1 apple, 267.9ms
# Speed: 4.0ms preprocess, 267.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Object 1 is: apple
# Coordinates are: [188.0830535888672, 252.40975952148438, 568.140869140625, 658.1294555664062]
# Confidence is: 0.93
# -------

# %%
ODImage(r'G:\Hesham_DL\Object Detection\fruits\orange_53.jpg')
# Out:
# image 1/1 G:\Hesham_DL\Object Detection\fruits\orange_53.jpg: 608x640 1 orange, 183.5ms
# Speed: 6.7ms preprocess, 183.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Object 1 is: orange
# Coordinates are: [322.6430969238281, 298.639404296875, 683.3251342773438, 651.9911499023438]
# Confidence is: 0.96
# -------
